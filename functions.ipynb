# %% [markdown]
# 1.what is python and why is it popular
# > python is a programming language that's popular because it's easy to learn, versatile and has many libraries
#
# 2.what is an interpreter is a python
# >a computer program that converts each high level program statement into machine code
#
# 3.what are pre-defined keywords in python
#  >keywords are used to define the syntax of the coding the keyword cannot be used as an identifier, function, or variable name all the keywords in python are written in lowercase except true and false
#
# 4.can  keywords be used as variable names
# >no keywords cannot be used as variable names in programming languages
#
# 5.what is mutability in python
# >in python ,mutability is the ability of an abject to change after it has been created
#
# 6.what are list mutable,but tuples are immutable
# >tupel use parentheses instead of square brackets,and the items in tuples cannot be modified
#
# 7.what is the difference between"==" and "is" operators in python
#
# >in python, the ==operator compares the values of two objects,while the is operator compares whether two variables point to the same object
#
# 8.what are logical operators in python
#
# >symbols or words that combine mutiple conditions intoa singel boolean expression
#
# 9.what is tpye casting in python
#
# >type casting ,also known as tpye conversion ,is the process of changing a variable's data type to another in python
#
# 10.what is the difference between implicit and explicit type casting
#
#  >implicit type casting is automatic while explicit type casting is manual implicit type casting is of-ten used to convert smaller data types to larger ones, while explicit type casting is used when data loss is possible.
#
#  11.what is the purpose of conditional statement in python
#
#  >control the flow of a progarm by deciding which parts of the code to run based on certain conditions
#
#  12.how does the elif statement work
#
#  > the first condition is false, it moves on to the next "elif" statement to check if that condition is ture
#
# 13.what is tohe difference between for and while loops
#
# >a "for" loop is used when you know exactly how many times you want to loop through a set of data, while a while loop repeats a block of code as lond as a specified condition remains true
#
# 14.describe a scenario where a while loop is more suitable than a for loop
#
# >situations where the number of iterations is not predetermined and depends on some dynamic condition
